# %%
import requests
import re
from bs4 import BeautifulSoup
from contextlib import closing

import json
import time

# %%
webpage = requests.get('https://www.goodreads.com/shelf/show/currently-reading?page=1')
soup = BeautifulSoup(webpage.text, 'html.parser')

# %%
tag = soup.find_all('a',class_='bookTitle')

# %%
tag[10]
# Out:
# <a class="bookTitle" href="/book/show/36072.The_7_Habits_of_Highly_Effective_People">The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change (Paperback)</a>

# %%
tag = tag[10]

# %%
tag["href"]
# Out:
# '/book/show/36072.The_7_Habits_of_Highly_Effective_People'

# %%
tag.text
# Out:
# 'The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change (Paperback)'

# %%
link = "https://www.goodreads.com" + tag['href']
link
# Out:
# 'https://www.goodreads.com/book/show/36072.The_7_Habits_of_Highly_Effective_People'

# %%
sub_page = requests.get(link)
sub_page
# Out:
# <Response [200]>

# %%
sub_soup = BeautifulSoup(sub_page.text, 'html.parser')
sub_soup
# Out:
# <!DOCTYPE html>
#
# <html class="desktop withSiteHeaderTopFullImage ">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# good_reads: http://ogp.me/ns/fb/good_reads#">
# <title>The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change by Stephen R. Covey</title>
# <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();
#  </script>
# <script type="text/javascript">
# ...

# %%
rating = sub_soup.find_all(itemprop="inLanguage")
rating
# Out:
# [<div class="infoBoxRowItem" itemprop="inLanguage">English</div>]

# %%
rating[0].text
# Out:
# 'English'
