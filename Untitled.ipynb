# %%
client = MongoClient()
db = client.capstone_1_db
collection = db.good_reads_best_books
data = pd.DataFrame(list(collection.find())).set_index("title")[:]

# %%
import pymongo
from pymongo import MongoClient
import pandas as pd

# %%
data.head()
# Out:
#                                                                _id  \
# title
# Moby-Dick, or, the Whale                  5c66eee813218a365547720d
# The Red Tent                              5c66eee913218a365547720e
# Harry Potter and the Prisoner of Azkaban  5c66eeeb13218a365547720f
# The Secret Life of Bees                   5c66eeec13218a3655477210
# Clockwork Angel                           5c66eeee13218a3655477211
#
#                                                    author  average_rating  \
# title
# Moby-Dick, or, the Whale                  Herman Melville            3.49
# The Red Tent                                Anita Diamant            4.17
# Harry Potter and the Prisoner of Azkaban     J.K. Rowling            4.55
# The Secret Life of Bees                     Sue Monk Kidd            4.03
# Clockwork Angel                           Cassandra Clare            4.33
#
#                                            birth_country  book_year  \
# title
# Moby-Dick, or, the Whale                   United States       1851
# The Red Tent                               United States       1997
# Harry Potter and the Prisoner of Azkaban  United Kingdom       1999
# The Secret Life of Bees                    United States       2001
# Clockwork Angel                                     Iran       2010
#
#                                                genre  number_of_ratings  votes
# title
# Moby-Dick, or, the Whale                    Classics             437409   2269
# The Red Tent                              Historical             475906   1989
# Harry Potter and the Prisoner of Azkaban     Fantasy            2287636   1984
# The Secret Life of Bees                      Fiction            1014338   2000
# Clockwork Angel                              Fantasy             579581   1800
